# %% [markdown]
# <a href="https://colab.research.google.com/github/ADII56-23/Machine_Leaning-lab/blob/main/exp0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
b=int(input())

a= a^b
b = a^b
a = a^b
print("a=",a)
print("b=",b)
# Out:
# 23
# 20
# a= 20
# b= 23

# %%
n = int(input())
fact = 1
for i in range(1,n+1):
  fact = fact*i
print(fact)
# Out:
# 5
# 120

# %%
num = int(input())
match num:
  case 0:
    print("zero")
  case _ if num >0:
    print("positive")
  case _ if num <0:
    print("negative")
# Out:
# -9
# negative
