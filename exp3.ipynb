# %% [markdown]
# <a href="https://colab.research.google.com/github/ADII56-23/Machine_Leaning-lab/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import Ridge

X = np.array([2, 3, 4]).reshape(-1, 1)
y = np.array([1, 2, 3])

model = Ridge(alpha=1)


model.fit(X, y)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)


pred = model.predict(X)
print("Predictions:", pred)
# Out:
# Coefficient: [0.66666667]
# Intercept: -4.440892098500626e-16
# Predictions: [1.33333333 2.         2.66666667]

# %%
import numpy as np

X = np.array([
    [1, 2, 1],
    [2, 3, 2],
    [3, 4, 3]
])

Y = np.array([
    [1],
    [2],
    [3]
])

lam = 1

I = np.eye(X.shape[1])

beta = np.linalg.inv(X.T @ X + lam * I) @ X.T @ Y

print("Regression Coefficients:")
print("beta0 =", beta[0][0])
print("beta1 =", beta[1][0])
print("beta2 =", beta[2][0])
# Out:
# Regression Coefficients:
# beta0 = 0.2857142857142855
# beta1 = 0.28571428571428636
# beta2 = 0.2857142857142849
